# %% [markdown]
# # 03 SynthWidget TutorialUse multiple oscillator types and compare waveform behavior.

# %%
import ipywidgets as widgetsfrom nbplay import SynthWidgetlead = SynthWidget(oscillator_type="saw", frequency=660.0, amplitude=0.55)bass = SynthWidget(oscillator_type="square", frequency=110.0, amplitude=0.65)texture = SynthWidget(oscillator_type="noise", amplitude=0.18)widgets.HBox([lead, bass, texture], layout=widgets.Layout(gap="16px"))
