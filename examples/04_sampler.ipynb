# %% [markdown]
# # 04 SamplerWidget TutorialLoad a generated sample and inspect ADSR behavior.

# %%
import mathfrom nbplay import SamplerWidgetsampler = SamplerWidget(attack=0.005, decay=0.08, sustain=0.15, release=0.12, max_voices=6)sample_rate = 44100duration_seconds = 0.18frame_count = int(sample_rate * duration_seconds)sample_data = [    math.sin(2 * math.pi * 880 * index / sample_rate) * (1 - index / frame_count)    for index in range(frame_count)]sampler.load_sample(sample_data, sample_rate=sample_rate, root_note=60, name="Notebook Blip")sampler
